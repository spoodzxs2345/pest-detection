# %% [markdown]
# <a href="https://colab.research.google.com/github/spoodzxs2345/pest-detection/blob/main/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Nov 17 06:18:21 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
cd /content/drive/MyDrive/object_counter_v3
# Out:
# /content/drive/MyDrive/object_counter_v3

# %%
pwd
# Out:
# '/content/drive/MyDrive/object_counter_v3'

# %%
# !pip install tensorflow==2.13.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.1/524.1 MB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 98.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 62.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 49.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.14.0
#     Uninstalling tensorflow-estimator-2.14.0:
#       Successfully uninstalled tensorflow-estimator-2.14.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.4
#     Uninstalling gast-0.5.4:
#       Successfully uninstalled gast-0.5.4
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.4/645.4 kB 8.9 MB/s eta 0:00:00
# ...

# %%
import os

HOME = os.getcwd()
print(HOME)
# Out:
# /content/drive/MyDrive/object_counter_v3

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/object_counter_v3/datasets’: File exists
# /content/drive/MyDrive/object_counter_v3/datasets

# %%
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/object_counter_v3/datasets/data.yaml epochs=100 imgsz=650 plots=True
# Out:
# /content/drive/MyDrive/object_counter_v3
# Ultralytics YOLOv8.0.211 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train4/confusion_matrix.png', width=600)
# Out:
# /content/drive/MyDrive/object_counter_v3

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train4/results.png', width=600)
# Out:
# /content/drive/MyDrive/object_counter_v3

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train4/val_batch0_pred.jpg', width=600)
# Out:
# /content/drive/MyDrive/object_counter_v3

# %%
# !yolo detect val model=/content/drive/MyDrive/object_counter_v3/runs/detect/train4/weights/best.pt data=/content/drive/MyDrive/object_counter_v3/datasets/data.yaml
# Out:
# Ultralytics YOLOv8.0.211 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/object_counter_v3/datasets/valid/labels.cache... 36 images, 0 backgrounds, 0 corrupt: 100% 36/36 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:03<00:00,  1.12s/it]
#                    all         36        993       0.57      0.469      0.483      0.195
#                  aphid         36        263      0.489      0.229       0.24     0.0899
#              fruit fly         36        313      0.694       0.61      0.682      0.292
#           scale_insect         36        417      0.527      0.568      0.526      0.202
# Speed: 0.3ms preprocess, 33.7ms inference, 0.0ms loss, 4.3ms postprocess per image
# Results saved to runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train4/weights/best.pt conf=0.25 source=/content/drive/MyDrive/object_counter_v3/datasets/test/images save=True
# Out:
# /content/drive/MyDrive/object_counter_v3
# Ultralytics YOLOv8.0.211 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/18 /content/drive/MyDrive/object_counter_v3/datasets/test/images/image-115-_jpg.rf.fe4c2ba33508977bd44d6579ee1c186f.jpg: 672x672 15 aphids, 9 scale_insects, 7.7ms
# image 2/18 /content/drive/MyDrive/object_counter_v3/datasets/test/images/image-119-_jpg.rf.1f860efcddd62aaba003122d9518fb25.jpg: 672x672 (no detections), 9.3ms
# image 3/18 /content/drive/MyDrive/object_counter_v3/datasets/test/images/image-125-_jpg.rf.33709e3424d3d0a22a57edc9834007f9.jpg: 672x672 4 fruit flys, 3 scale_insects, 12.6ms
# image 4/18 /content/drive/MyDrive/object_counter_v3/datasets/test/images/image-13-_jpg.rf.a535af1d82d41058b977542a7611f5da.jpg: 672x672 2 aphids, 10.1ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict5/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
# !yolo export model=yolov8n.pt  # export official model
# !yolo export model=/content/drive/MyDrive/object_counter_v3/runs/detect/train4/weights/best.pt  # export custom trained model
# Out:
# WARNING ⚠️ 'format' is missing. Using default 'format=torchscript'.
# Ultralytics YOLOv8.0.211 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.00GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# TorchScript: starting export with torch 2.1.0+cu118...
# TorchScript: export success ✅ 2.0s, saved as 'yolov8n.torchscript' (12.4 MB)
#
# Export complete (4.1s)
# Results saved to /content/drive/MyDrive/object_counter_v3
# Predict:         yolo predict task=detect model=yolov8n.torchscript imgsz=640
# Validate:        yolo val task=detect model=yolov8n.torchscript imgsz=640 data=coco.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export
# WARNING ⚠️ 'format' is missing. Using default 'format=torchscript'.
# ...
